# %% [markdown]
# #### Text Data Exploration & Visualization
# - http://www.nltk.org/api/nltk.html#nltk.text.Text

# %% [markdown]
# <br>
# #### 1. 가장 많이 등장하는 단어 추출하기

# %% [markdown]
# #### 1) 영화 Dark Knight 리뷰에서 많이 등장하는 명사 추출하기

# %%
import nltk
from nltk.corpus import stopwords
from collections import Counter

# 1) Stopwords 준비하기
stop_words = stopwords.words("english")
stop_words.append(',')
stop_words.append('.')
stop_words.append('’')
stop_words.append('”')
stop_words.append('—')

# 2) Text data 준비하기
with open('darkknight.txt', 'r', encoding="utf-8") as f:  # 읽기 형식('r')로 지정하고 인코딩은 'utf-8'로 설정한다
    lines = f.readlines()  # readlines 함수로 텍스트 파일의 내용을 읽어 리스트로 저장한다
    f.close()  # 파일을 닫는다

tokens = []
wordList = []

# 3) Tokenizing
for line in lines:  # for문을 통해 각 줄에 접근한다
    tokenized = nltk.word_tokenize(line)  # 각 줄을 tokenize한다
#     print(tokenized)
    for token in tokenized:
        if token.lower() not in stop_words:
            tokens.append(token)

# 4) POS Tagging - 명사 종류만 모으기
tags = nltk.pos_tag(tokens)  # tokenize한 결과를 품사 태깅한다
print(tags)
# print(tags)
for word, tag in tags:  # for 문을 통해 각각의 (단어, 태그) 쌍에 접근
    if tag in ['NN', 'NNS', 'NNP', 'NNPS']:  # 만약 태그가 명사 종류이면:
        wordList.append(word.lower())  # 소문자로 변환한 후 리스트에 첨부한다

counts = Counter(wordList)  # 각 명사의 숫자를 센 결과를 변수에 저장한다 (Counter -> {'home': 15, '단어':출현횟수, ...})
# print(counts)
print(counts.most_common(10))  # 가장 많이 등장한 10개 명사를 출력한다
# Out:
# [("'ve", 'VBP'), ('subjected', 'VBN'), ('enormous', 'JJ'), ('amount', 'NN'), ('hype', 'NN'), ('marketing', 'NN'), ('Dark', 'NNP'), ('Knight', 'NNP'), ("'ve", 'VBP'), ('seen', 'VBN'), ('Joker', 'NNP'), ('scavenger', 'NN'), ('hunt', 'NN'), ('one', 'CD'), ('largest', 'JJS'), ('viral', 'JJ'), ('campaign', 'NN'), ('advertising', 'VBG'), ('history', 'NN'), ('culminates', 'NNS'), ('actual', 'JJ'), ('release', 'NN'), ('movie.Everything', 'NN'), ("'s", 'POS'), ('said', 'VBD'), ('pretty', 'RB'), ('much', 'JJ'), ('spot', 'NN'), ('first', 'JJ'), ('time', 'NN'), ('remember', 'VB'), ('summer', 'NN'), ('blockbuster', 'NN'), ('film', 'NN'), ('far', 'RB'), ('surpasses', 'VBZ'), ('hype.For', 'JJ'), ('much', 'JJ'), ('action', 'NN'), ('movie', 'NN'), ("'s", 'POS'), ('acting', 'JJ'), ('make', 'NN'), ('great', 'JJ'), ('piece', 'NN'), ('work', 'NN'), ('punch', 'JJ'), ('explosion', 'NN'), ('stunt-work', 'NN'), ('great', 'JJ'), ('dialog', 'NN'), ('work', 'NN'), ('actor', 'NN'), ('moments.Bale', 'NN'), ("'s", 'POS'), ('Batman', 'NNP'), ('definitive', 'JJ'), ('Batman', 'NNP'), ('see', 'VBP'), ('everything', 'NN'), ('character', 'NN'), ('finally', 'RB'), ('film', 'NN'), ('Martial', 'NNP'), ('art', 'NN'), ('skill', 'NN'), ('cunning', 'VBG'), ('great', 'JJ'), ('tactical', 'JJ'), ('thinking', 'NN'), ('forensic', 'JJ'), ('application', 'NN'), ('technological', 'JJ'), ('genius', 'NN'), ('advance', 'NN'), ('improve', 'VBP'), ('Luscious', 'NNP'), ('Fox', 'NNP'), ("'s", 'POS'), ('inventions/technological', 'JJ'), ('breakthrough', 'NN'), ('intimidating', 'NN'), ('personality', 'NN'), ('even', 'RB'), ('little', 'JJ'), ('swashbuckling', 'VBG'), ('Heath', 'NNP'), ('yes', 'UH'), ('get', 'VB'), ('credit', 'NN'), ('performance', 'NN'), ('Joker', 'NNP'), ('also', 'RB'), ('recognize', 'VBP'), ('Jonathan', 'NNP'), ('Chris', 'NNP'), ('Nolan', 'NNP'), ('writing', 'VBG'), ('treatment', 'NN'), ('character', 'NN'), ("'s", 'POS'), ('fact', 'NN'), ('Ledger', 'NNP'), ('make', 'VBP'), ('Joker', 'NNP'), ('menacing', 'NN'), ('Nolans', 'NNPS'), ('given', 'VBN'), ('character', 'NN'), ('great', 'JJ'), ('manifesto', 'JJ'), ('drive', 'NN'), ('action', 'NN'), ('Joker', 'NNP'), ("'s", 'POS'), ('stance', 'NN'), ('chaos', 'NN'), ('order', 'NN'), ('anarchy', 'JJ'), ('morality', 'NN'), ('average', 'JJ'), ('modern', 'JJ'), ('human', 'JJ'), ('make', 'VBP'), ('character', 'NN'), ('interesting', 'VBG'), ('psychologically', 'RB'), ('Nolans', 'NNPS'), ('drafted', 'VBD'), ('complex', 'JJ'), ('character', 'NN'), ('perfect', 'NN'), ('performance', 'NN'), ('could', 'MD'), ("'ve", 'VBP'), ('pulled', 'VBN'), ('something', 'NN'), ('like', 'IN'), ("'s", 'POS'), ('difficult', 'JJ'), ('role', 'NN'), ("'s", 'POS'), ('Ledger', 'NNP'), ("'s", 'POS'), ('performance', 'NN'), ('great.This', 'VBP'), ("n't", 'RB'), ('action', 'NN'), ('movie', 'NN'), ("'s", 'POS'), ('film', 'NN'), ('explores', 'VBZ'), ('literary', 'JJ'), ('theme', 'NN'), ('hero', 'NN'), ('villain', 'NN'), ('well', 'RB'), ('order', 'NN'), ('anarchy', 'JJ'), ('Yes', 'NNP'), ('listen', 'VBD'), ('dialog', 'NN'), ("'s", 'POS'), ('Christopher', 'NNP'), ('Nolan', 'NNP'), ("'s", 'POS'), ('second', 'JJ'), ('bundle', 'NN'), ('joy', 'NN'), ('``', '``'), ('Dark', 'NNP'), ('Knight', 'NNP'), ('``', '``'), ('EXCEEDED', 'NNP'), ('expectation', 'NN'), ('!', '.'), ('!', '.'), ('!', '.'), ('success', 'NN'), ('2005', 'CD'), ("'s", 'POS'), ('reboot', 'JJ'), ('Batman', 'NNP'), ('franchise', 'NN'), ('took', 'VBD'), ('already', 'RB'), ('established', 'VBN'), ('expanded', 'VBN'), ('amped', 'NNS'), ('gave', 'VBD'), ('deeper', 'JJR'), ('darker', 'NN'), ('brooding', 'VBG'), ('story', 'NN'), ('gripping', 'VBG'), ('suspense', 'NN'), ('likely', 'JJ'), ('catch', 'NN'), ('guard', 'RB'), ('several', 'JJ'), ('time', 'NN'), ('throughout', 'IN'), ('Christian', 'JJ'), ('Bale', 'NNP'), ('delf', 'NN'), ('deeper', 'NN'), ('Batman', 'NNP'), ('sworn', 'VBD'), ('fight', 'JJ'), ('evil', 'JJ'), ('injustice', 'NN'), ('though', 'IN'), ('also', 'RB'), ('quite', 'RB'), ('reluctant', 'JJ'), ('uncertai ...
# [('movie', 405), ('batman', 303), ('film', 283), ('joker', 219), ('dark', 136), ('ledger', 131), ('knight', 124), ('time', 112), ('heath', 110), ('performance', 87)]

# %% [markdown]
# #### 2) 영화 Dark Knight 리뷰에서 많이 등장하는 형용사 추출하기

# %%
import nltk
from nltk.corpus import stopwords
from collections import Counter

# 1) Stopwords 준비하기
stop_words = stopwords.words("english")
stop_words.append(',')
stop_words.append('.')
stop_words.append('’')
stop_words.append('”')
stop_words.append('—')

# 2) Text data 준비하기
with open('darkknight.txt', 'r', encoding="utf-8") as f:  # 읽기 형식('r')로 지정하고 인코딩은 'utf-8'로 설정한다
    lines = f.readlines()  # readlines 함수로 텍스트 파일의 내용을 읽어 리스트로 저장한다
    f.close()  # 파일을 닫는다

tokens = []
wordList = []

# 3) Tokenizing
for line in lines:  # for문을 통해 각 줄에 접근한다
    tokenized = nltk.word_tokenize(line)  # 각 줄을 tokenize한다
    for token in tokenized:
        if token.lower() not in stop_words:
            tokens.append(token)

# 4) POS Tagging - 형용사 종류만 모으기
tags = nltk.pos_tag(tokens)  # tokenize한 결과를 품사 태깅한다
for word, tag in tags:  # for 문을 통해 각각의 (단어, 태그) 쌍에 접근
    if tag in ['JJ', 'JJR', 'JS']:  # 만약 태그가 형용사 종류이면:
        wordList.append(word.lower())  # 소문자로 변환한 후 리스트에 첨부한다

counts = Counter(wordList)  # 각 형용사의 숫자를 센 결과를 변수에 저장한다 (Counter -> {'home': 15, '단어':출현횟수, ...})
# print(counts)
print(counts.most_common(10))  # 가장 많이 등장한 10개 형용사를 출력한다
# Out:
# [('good', 141), ('great', 78), ('many', 54), ('much', 52), ('comic', 43), ('real', 29), ('bad', 28), ('little', 26), ('new', 25), ('last', 22)]

# %% [markdown]
# #### 3) 영화 Dark Knight 리뷰에서 많이 등장하는 동사 추출하기

# %%
import nltk
from nltk.corpus import stopwords
from collections import Counter

# 1) Stopwords 준비하기
stop_words = stopwords.words("english")
stop_words.append(',')
stop_words.append('.')
stop_words.append('’')
stop_words.append('”')
stop_words.append('—')

# 2) Text data 준비하기
with open('darkknight.txt', 'r', encoding="utf-8") as f:  # 읽기 형식('r')로 지정하고 인코딩은 'utf-8'로 설정한다
    lines = f.readlines()  # readlines 함수로 텍스트 파일의 내용을 읽어 리스트로 저장한다
    f.close()  # 파일을 닫는다

tokens = []
wordList = []

# 3) Tokenizing
for line in lines:  # for문을 통해 각 줄에 접근한다
    tokenized = nltk.word_tokenize(line)  # 각 줄을 tokenize한다
    for token in tokenized:
        if token.lower() not in stop_words:
            tokens.append(token)

# 4) POS Tagging - 동사 종류만 모으기
tags = nltk.pos_tag(tokens)  # tokenize한 결과를 품사 태깅한다
for word, tag in tags:  # for 문을 통해 각각의 (단어, 태그) 쌍에 접근
    if tag in ['VB', 'VBD', 'VBN', 'VBP', 'VBZ']:  # 만약 태그가 동사 종류이면:
        wordList.append(word.lower())  # 소문자로 변환한 후 리스트에 첨부한다

counts = Counter(wordList)  # 각 동사의 숫자를 센 결과를 변수에 저장한다 (Counter -> {'home': 15, '단어':출현횟수, ...})
# print(counts)
print(counts.most_common(10))  # 가장 많이 등장한 10개 동사를 출력한다
# Out:
# [('see', 59), ('get', 53), ('made', 49), ('think', 45), ('seen', 45), ('make', 45), ('say', 41), ("'ve", 37), ("'m", 32), ('go', 30)]

# %% [markdown]
# <br>
# <br>
# #### 2. 영화 Dark Knight 리뷰에서 등장하는 토큰 개수 확인하기

# %%
import nltk
from nltk.corpus import stopwords

stop_words = stopwords.words("english")
stop_words.append(',')
stop_words.append('.')
stop_words.append('’')
stop_words.append('”')
stop_words.append('—')
stop_words.append('else')
stop_words.append('$')

with open('darkknight.txt', 'r', encoding="utf-8") as f:  # 읽기 형식('r')로 지정하고 인코딩은 'utf-8'로 설정한다
    lines = f.readlines()  # readlines 함수로 텍스트 파일의 내용을 읽어 리스트로 저장한다
    f.close()  # 파일을 닫는다

tokens = []

for line in lines:  # for문을 통해 각 줄에 접근한다
    tokenized = nltk.word_tokenize(line)  # 각 줄을 tokenize한다
    for token in tokenized:
        if token.lower() not in stop_words:
            tokens.append(token)

corpus = nltk.Text(tokens)
print(corpus)
print(len(corpus.tokens))  # 전체 token의 개수를 출력한다
print(len(set(corpus.tokens)))  # unique한 token의 개수를 출력한다
# Out:
# <Text: 've subjected enormous amount hype marketing Dark Knight...>
# 18439
# 4648

# %% [markdown]
# <br>
# <br>
# #### 3. 토큰의 등장 횟수 시각화하기

# %%
import nltk
from nltk.corpus import stopwords
from collections import Counter
import matplotlib.pyplot as plt
import re

stop_words = stopwords.words("english")
stop_words.append('else')

with open('darkknight.txt', 'r', encoding="utf-8") as f:  # 읽기 형식('r')로 지정하고 인코딩은 'utf-8'로 설정한다
    lines = f.readlines()  # readlines 함수로 텍스트 파일의 내용을 읽어 리스트로 저장한다
    f.close()  # 파일을 닫는다
    
tokens = []

for line in lines:  # for문을 통해 각 줄에 접근한다
    tokenized = nltk.word_tokenize(line)  # 각 줄을 tokenize한다
    for token in tokenized: # 각 Token이
        if token.lower() not in stop_words: # Stopwords 리스트에 포함되어 있지 않으며,
            if re.match('^[a-zA-Z]+', token): # 특수 기호에 해당하지 않을 경우,
                tokens.append(token) # Token list 에 추가해준다.
        
corpus = nltk.Text(tokens) 
# print(tokens)
print(corpus)
plt.figure(figsize=(10, 3)) 
plt.title('Top 25 Words',fontsize=30)
corpus.plot(25) # 25개까지만 확인
# Out:
# <Text: subjected enormous amount hype marketing Dark Knight seen...>

# %% [markdown]
# <br>
# <br>
# #### 4. 문맥 상 유사한 단어 출력하기

# %%
import nltk
from nltk.corpus import stopwords
from collections import Counter
import matplotlib.pyplot as plt
import re

stop_words = stopwords.words("english")
stop_words.append('else')

with open('darkknight.txt', 'r', encoding="utf-8") as f:  # 읽기 형식('r')로 지정하고 인코딩은 'utf-8'로 설정한다
    lines = f.readlines()  # readlines 함수로 텍스트 파일의 내용을 읽어 리스트로 저장한다
    f.close()  # 파일을 닫는다
    
tokens = []

for line in lines:  # for문을 통해 각 줄에 접근한다
    tokenized = nltk.word_tokenize(line)  # 각 줄을 tokenize한다
    for token in tokenized: # 각 Token이
        if token.lower() not in stop_words: # Stopwords 리스트에 포함되어 있지 않으며,
            if re.match('^[a-zA-Z]+', token): # 특수 기호에 해당하지 않을 경우,
                tokens.append(token) # Token list 에 추가해준다.
        
corpus = nltk.Text(tokens) 

print('Similar words : ')
corpus.similar('batman')
# Out:
# Similar words :
# superhero action better character film movie iconic end come heath
# forever stolen another second best director villain storyline good
# render

# %% [markdown]
# <br>
# <br>
# #### 5. 텍스트의 연어(collocation) 출력하기

# %%
import nltk
from nltk.corpus import stopwords
from collections import Counter
import matplotlib.pyplot as plt
import re

stop_words = stopwords.words("english")
stop_words.append('else')

with open('darkknight.txt', 'r', encoding="utf-8") as f:  # 읽기 형식('r')로 지정하고 인코딩은 'utf-8'로 설정한다
    lines = f.readlines()  # readlines 함수로 텍스트 파일의 내용을 읽어 리스트로 저장한다
    f.close()  # 파일을 닫는다
    
tokens = []

for line in lines:  # for문을 통해 각 줄에 접근한다
    tokenized = nltk.word_tokenize(line)  # 각 줄을 tokenize한다
    for token in tokenized: # 각 Token이
        if token.lower() not in stop_words: # Stopwords 리스트에 포함되어 있지 않으며,
            if re.match('^[a-zA-Z]+', token): # 특수 기호에 해당하지 않을 경우,
                tokens.append(token) # Token list 에 추가해준다.
        
corpus = nltk.Text(tokens) 

print('Collocation')
corpus.collocations()
# Out:
# Collocation
# Dark Knight; Heath Ledger; Christian Bale; comic book; Harvey Dent;
# Christopher Nolan; Bruce Wayne; Aaron Eckhart; Morgan Freeman; Gary
# Oldman; Batman Begins; Two Face; Gotham City; Maggie Gyllenhaal;
# Rachel Dawes; Michael Caine; special effect; Tim Burton; Jack
# Nicholson; dark knight
